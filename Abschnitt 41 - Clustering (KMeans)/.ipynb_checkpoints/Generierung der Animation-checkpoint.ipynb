# %%
# !pip install moviepy
# !pip install pygame

import moviepy
# Out:
# Requirement already satisfied: moviepy in /Users/jannisseemann/anaconda3/lib/python3.6/site-packages
# Requirement already satisfied: imageio==2.1.2 in /Users/jannisseemann/anaconda3/lib/python3.6/site-packages (from moviepy)
# Requirement already satisfied: numpy in /Users/jannisseemann/anaconda3/lib/python3.6/site-packages (from moviepy)
# Requirement already satisfied: decorator==4.0.11 in /Users/jannisseemann/anaconda3/lib/python3.6/site-packages (from moviepy)
# Requirement already satisfied: tqdm==4.11.2 in /Users/jannisseemann/anaconda3/lib/python3.6/site-packages (from moviepy)
# Requirement already satisfied: pillow in /Users/jannisseemann/anaconda3/lib/python3.6/site-packages (from imageio==2.1.2->moviepy)
# Requirement already satisfied: olefile in /Users/jannisseemann/anaconda3/lib/python3.6/site-packages (from pillow->imageio==2.1.2->moviepy)
# Requirement already satisfied: pygame in /Users/jannisseemann/anaconda3/lib/python3.6/site-packages

# %%
from sklearn.datasets import make_blobs
X, y = make_blobs(n_samples=200, n_features=2, cluster_std=1.25, centers=[(-5, -5), (0, 0), (5, 5)], shuffle=False, random_state=0)

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

plt.scatter(X[:, 0], X[:, 1])
plt.show()

# %%
from sklearn.cluster import KMeans

# %%
from moviepy.editor import VideoClip
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas
from matplotlib.figure import Figure
import numpy as np
from moviepy.video.io.bindings import mplfig_to_npimage


n_clusters = 3

def make_figure(t):
    fig = Figure(dpi = 1600)
    canvas = FigureCanvas(fig)
    ax = fig.gca()

    if t == 0:
        ax.scatter(X[:, 0], X[:, 1], alpha = 0.3)
        ax.set_title("KMeans (Vorher)")
    else:
        ax.set_title("KMeans (Schritt #" + str(int(t)) + ")")
        model = KMeans(n_clusters=n_clusters, random_state = 44, max_iter=t, n_init = 1, init = "random")
        model.fit(X)
        
        for label in range(0, n_clusters):
            color = plt.cm.Dark2(label)
            print(color)
            
            ax.scatter(
                model.cluster_centers_[label, 0], 
                model.cluster_centers_[label, 1], 
                marker = "X", 
                s = 100,
                color = color
            )
            
            ax.scatter(
                X[model.labels_ == label, 0], 
                X[model.labels_ == label, 1], 
                color = color,
                alpha = 0.5
            )
    return fig

def make_frame(t):
    fig = make_figure(t)
    return mplfig_to_npimage(fig)

animation = VideoClip(make_frame, duration=7).resize(0.125)
animation.ipython_display("m.gif", fps=1, loop=True, autoplay=True, width=500)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#  12%|█▎        | 1/8 [00:02<00:15,  2.17s/it]
# (0.10588235294117647, 0.61960784313725492, 0.46666666666666667, 1.0)
#  25%|██▌       | 2/8 [00:03<00:12,  2.01s/it]
# (0.85098039215686272, 0.37254901960784315, 0.0078431372549019607, 1.0)
# (0.45882352941176469, 0.4392156862745098, 0.70196078431372544, 1.0)
# (0.10588235294117647, 0.61960784313725492, 0.46666666666666667, 1.0)
# (0.85098039215686272, 0.37254901960784315, 0.0078431372549019607, 1.0)
#  38%|███▊      | 3/8 [00:05<00:09,  1.98s/it]
# (0.45882352941176469, 0.4392156862745098, 0.70196078431372544, 1.0)
# (0.10588235294117647, 0.61960784313725492, 0.46666666666666667, 1.0)
# (0.85098039215686272, 0.37254901960784315, 0.0078431372549019607, 1.0)
# (0.45882352941176469, 0.4392156862745098, 0.70196078431372544, 1.0)
#  50%|█████     | 4/8 [00:07<00:07,  1.90s/it]
# (0.10588235294117647, 0.61960784313725492, 0.46666666666666667, 1.0)
# (0.85098039215686272, 0.37254901960784315, 0.0078431372549019607, 1.0)
# (0.45882352941176469, 0.4392156862745098, 0.70196078431372544, 1.0)
#  62%|██████▎   | 5/8 [00:09<00:05,  1.86s/it]
# (0.10588235294117647, 0.61960784313725492, 0.46666666666666667, 1.0)
# (0.85098039215686272, 0.37254901960784315, 0.0078431372549019607, 1.0)
#  75%|███████▌  | 6/8 [00:10<00:03,  1.82s/it]
# (0.45882352941176469, 0.4392156862745098, 0.70196078431372544, 1.0)
# (0.10588235294117647, 0.61960784313725492, 0.46666666666666667, 1.0)
#  88%|████████▊ | 7/8 [00:12<00:01,  1.79s/it]
# (0.85098039215686272, 0.37254901960784315, 0.0078431372549019607, 1.0)
# (0.45882352941176469, 0.4392156862745098, 0.70196078431372544, 1.0)
# <div align=middle><video loop='True' autoplay='True' width='500'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %%
animation.write_gif("kmeans.gif", fps = 1)
# Out:
# [MoviePy] Building file kmeans.gif with imageio
#   0%|          | 0/8 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#  12%|█▎        | 1/8 [00:01<00:12,  1.83s/it]
# (0.10588235294117647, 0.61960784313725492, 0.46666666666666667, 1.0)
# (0.85098039215686272, 0.37254901960784315, 0.0078431372549019607, 1.0)
# (0.45882352941176469, 0.4392156862745098, 0.70196078431372544, 1.0)
#  25%|██▌       | 2/8 [00:03<00:10,  1.80s/it]
# (0.10588235294117647, 0.61960784313725492, 0.46666666666666667, 1.0)
# (0.85098039215686272, 0.37254901960784315, 0.0078431372549019607, 1.0)
# (0.45882352941176469, 0.4392156862745098, 0.70196078431372544, 1.0)
#  38%|███▊      | 3/8 [00:05<00:08,  1.78s/it]
# (0.10588235294117647, 0.61960784313725492, 0.46666666666666667, 1.0)
# (0.85098039215686272, 0.37254901960784315, 0.0078431372549019607, 1.0)
# (0.45882352941176469, 0.4392156862745098, 0.70196078431372544, 1.0)
#  50%|█████     | 4/8 [00:06<00:07,  1.75s/it]
# (0.10588235294117647, 0.61960784313725492, 0.46666666666666667, 1.0)
# (0.85098039215686272, 0.37254901960784315, 0.0078431372549019607, 1.0)
# (0.45882352941176469, 0.4392156862745098, 0.70196078431372544, 1.0)
#  62%|██████▎   | 5/8 [00:08<00:05,  1.76s/it]
# (0.10588235294117647, 0.61960784313725492, 0.46666666666666667, 1.0)
# (0.85098039215686272, 0.37254901960784315, 0.0078431372549019607, 1.0)
# (0.45882352941176469, 0.4392156862745098, 0.70196078431372544, 1.0)
#  75%|███████▌  | 6/8 [00:10<00:03,  1.79s/it]
# (0.10588235294117647, 0.61960784313725492, 0.46666666666666667, 1.0)
# (0.85098039215686272, 0.37254901960784315, 0.0078431372549019607, 1.0)
#  88%|████████▊ | 7/8 [00:12<00:01,  1.81s/it]
# (0.45882352941176469, 0.4392156862745098, 0.70196078431372544, 1.0)

# %%
from sklearn.metrics import silhouette_score

clusters = range(2, 10)
scores = []

for i in clusters:
    model = KMeans(n_clusters=i)
    model.fit(X)
    
    print(silhouette_score(X, model.labels_, metric='euclidean'))
    scores.append(model.score(X))
    
# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot(clusters, scores)
# Out:
# 0.588492791732
# 0.662647978718
# 0.537762392428
# 0.409467545925
# 0.331095446305
# 0.330993547721
# 0.324763789404
# 0.342754673737
