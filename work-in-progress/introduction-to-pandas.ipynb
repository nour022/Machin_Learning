# %%
import pandas as pd

# %%
series = pd.Series(["BMW","Toyota","Honda"])

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
colours = pd.Series(["Red","Blue","white"])

# %%
colours
# Out:
# 0      Red
# 1     Blue
# 2    white
# dtype: object

# %%
car_data = pd.DataFrame({"CarMake":series,"Colour":colours})
car_data
# Out:
#   CarMake Colour
# 0     BMW    Red
# 1  Toyota   Blue
# 2   Honda  white

# %%
# import data 
cars = pd.read_csv("car-sales.csv")

# %%
cars
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
#Exporting a dataFrem
cars.to_csv("exported-car-sales.csv",index=False)

# %%
expcarsales = pd.read_csv("exported-car-sales.csv")

# %%
expcarsales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
heart_dis = pd.read_csv("https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/heart-disease.csv")

# %%
heart_dis
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %% [markdown]
#     ## Describe data

# %%
# Attribute
cars.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
cars.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
cars.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
cars.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
#cars.mean()

# %%
cars.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
cars["Doors"].sum()
# Out:
# 40

# %%
len(cars["Doors"])
# Out:
# 10

# %%
cars.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
cars.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# .loc & .iloc
animals = pd.Series(["cat","dog","bird","panda","snake"])

# %%
animals.loc[3]
# Out:
# 'panda'

# %%
# .loc refers to index

cars.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
# .iloc refers to position
animals.iloc[3]
# Out:
# 'panda'

# %%
cars.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animals.iloc[:3]
# Out:
# 0     cat
# 1     dog
# 2    bird
# dtype: object

# %%
cars["Colour"]
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
cars.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
cars[cars["Colour"]=="Red"]
# Out:
#     Make Colour  Odometer (KM)  Doors      Price
# 1  Honda    Red          87899      4  $5,000.00

# %%
pd.crosstab(cars["Make"],cars["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
# Groupby 
cars.groupby(["Make"]).mean("Odemeter (KM) ","Doors")
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
cars["Odometer (KM)"].plot()
# Out:
# <Axes: >

# %%
# %matplotlib inline

# %%
cars["Odometer (KM)"].plot(kind="bar")
# Out:
# <Axes: >

# %%
cars["Odometer (KM)"].hist()
# Out:
# <Axes: >

# %%
cars["Price"].dtype
# Out:
# dtype('O')

# %%
cars["Make"].str.upper()
# Out:
# 0    TOYOTA
# 1     HONDA
# 2    TOYOTA
# 3       BMW
# 4    NISSAN
# 5    TOYOTA
# 6     HONDA
# 7     HONDA
# 8    TOYOTA
# 9    NISSAN
# Name: Make, dtype: object

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
 car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(),inplace=True) #car_sales_missing["Odometer"]=

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna() ## remove row wehre missing data
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
sears_column  =pd.Series([5,5,5,5])

# %%
cars["Seats"] = sears_column

# %%
cars
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats
# 0  Toyota  White         150043      4   $4,000.00    5.0
# 1   Honda    Red          87899      4   $5,000.00    5.0
# 2  Toyota   Blue          32549      3   $7,000.00    5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0
# 4  Nissan  White         213095      4   $3,500.00    NaN
# 5  Toyota  Green          99213      4   $4,500.00    NaN
# 6   Honda   Blue          45698      4   $7,500.00    NaN
# 7   Honda   Blue          54738      4   $7,000.00    NaN
# 8  Toyota  White          60000      4   $6,250.00    NaN
# 9  Nissan  White          31600      4   $9,700.00    NaN

# %%
cars["Seats"].fillna(5,inplace=True)

# %%
cars
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats
# 0  Toyota  White         150043      4   $4,000.00    5.0
# 1   Honda    Red          87899      4   $5,000.00    5.0
# 2  Toyota   Blue          32549      3   $7,000.00    5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0
# 4  Nissan  White         213095      4   $3,500.00    5.0
# 5  Toyota  Green          99213      4   $4,500.00    5.0
# 6   Honda   Blue          45698      4   $7,500.00    5.0
# 7   Honda   Blue          54738      4   $7,000.00    5.0
# 8  Toyota  White          60000      4   $6,250.00    5.0
# 9  Nissan  White          31600      4   $9,700.00    5.0

# %%
# Column from Pyton list 
fuel_ec = [9.8,1.1,2.1,9.8,1.1,2.1,3.0,1.1,2.1,3.0]
cars["Fuwl per 100KM"]=fuel_ec

# %%
cars
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuwl per 100KM
# 0  Toyota  White         150043      4   $4,000.00    5.0             9.8
# 1   Honda    Red          87899      4   $5,000.00    5.0             1.1
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             2.1
# 3     BMW  Black          11179      5  $22,000.00    5.0             9.8
# 4  Nissan  White         213095      4   $3,500.00    5.0             1.1
# 5  Toyota  Green          99213      4   $4,500.00    5.0             2.1
# 6   Honda   Blue          45698      4   $7,500.00    5.0             3.0
# 7   Honda   Blue          54738      4   $7,000.00    5.0             1.1
# 8  Toyota  White          60000      4   $6,250.00    5.0             2.1
# 9  Nissan  White          31600      4   $9,700.00    5.0             3.0

# %%
    # select only 20% of data
cars.sample(frac=0.2)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  Seats  Fuwl per 100KM
# 2  Toyota   Blue          32549      3  $7,000.00    5.0             2.1
# 6   Honda   Blue          45698      4  $7,500.00    5.0             3.0

# %%
cars.reset_index(drop=True,inplace=True)  #

# %%
cars
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuwl per 100KM
# 0  Toyota  White         150043      4   $4,000.00    5.0             9.8
# 1   Honda    Red          87899      4   $5,000.00    5.0             1.1
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             2.1
# 3     BMW  Black          11179      5  $22,000.00    5.0             9.8
# 4  Nissan  White         213095      4   $3,500.00    5.0             1.1
# 5  Toyota  Green          99213      4   $4,500.00    5.0             2.1
# 6   Honda   Blue          45698      4   $7,500.00    5.0             3.0
# 7   Honda   Blue          54738      4   $7,000.00    5.0             1.1
# 8  Toyota  White          60000      4   $6,250.00    5.0             2.1
# 9  Nissan  White          31600      4   $9,700.00    5.0             3.0

# %%
cars["Odometer (KM)"]=cars["Odometer (KM)"].apply(lambda x:x/1.6)
cars
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuwl per 100KM
# 0  Toyota  White      93776.875      4   $4,000.00    5.0             9.8
# 1   Honda    Red      54936.875      4   $5,000.00    5.0             1.1
# 2  Toyota   Blue      20343.125      3   $7,000.00    5.0             2.1
# 3     BMW  Black       6986.875      5  $22,000.00    5.0             9.8
# 4  Nissan  White     133184.375      4   $3,500.00    5.0             1.1
# 5  Toyota  Green      62008.125      4   $4,500.00    5.0             2.1
# 6   Honda   Blue      28561.250      4   $7,500.00    5.0             3.0
# 7   Honda   Blue      34211.250      4   $7,000.00    5.0             1.1
# 8  Toyota  White      37500.000      4   $6,250.00    5.0             2.1
# 9  Nissan  White      19750.000      4   $9,700.00    5.0             3.0

# %%
newSet = pd.merge(cars,car_sales_missing ,on='Make' ,how='inner')

# %%
newSet
# Out:
#       Make Colour_x  Odometer (KM)  Doors_x     Price_x  Seats  \
# 0   Toyota    White      93776.875        4   $4,000.00    5.0
# 1   Toyota    White      93776.875        4   $4,000.00    5.0
# 2   Toyota    White      93776.875        4   $4,000.00    5.0
# 3   Toyota    White      93776.875        4   $4,000.00    5.0
# 4   Toyota     Blue      20343.125        3   $7,000.00    5.0
# 5   Toyota     Blue      20343.125        3   $7,000.00    5.0
# 6   Toyota     Blue      20343.125        3   $7,000.00    5.0
# 7   Toyota     Blue      20343.125        3   $7,000.00    5.0
# 8   Toyota    Green      62008.125        4   $4,500.00    5.0
# 9   Toyota    Green      62008.125        4   $4,500.00    5.0
# 10  Toyota    Green      62008.125        4   $4,500.00    5.0
# 11  Toyota    Green      62008.125        4   $4,500.00    5.0
# 12  Toyota    White      37500.000        4   $6,250.00    5.0
# 13  Toyota    White      37500.000        4   $6,250.00    5.0
# ...
